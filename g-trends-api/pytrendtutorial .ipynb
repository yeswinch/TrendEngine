# %%
import pandas as pd
from pytrends.request import TrendReq

pytrends = TrendReq()

pytrends.build_payload(kw_list=['Taylor Swift'])

# %%
# Interest by Region
df = pytrends.interest_by_region()
df.head(10) #shows first 10 rows
# Out:
#                    Taylor Swift
# geoName
# Afghanistan                   0
# Albania                       0
# Algeria                      13
# American Samoa                0
# Andorra                       0
# Angola                        0
# Anguilla                      0
# Antarctica                    0
# Antigua & Barbuda             0
# Argentina                    20

# %%
# Interest over Time
pytrends.interest_over_time() #shows first/last 5 rows
# Out:
#             Taylor Swift isPartial
# date
# 2016-04-03            36     False
# 2016-04-10            30     False
# 2016-04-17            33     False
# 2016-04-24            28     False
# 2016-05-01            31     False
# ...                  ...       ...
# 2021-02-21            13     False
# 2021-02-28            15     False
# 2021-03-07            13     False
# 2021-03-14            26     False
# 2021-03-21            14      True
#
# [260 rows x 2 columns]

# %%
#Plot Interest by Region in Bar Graph
df.reset_index().plot(x='geoName', y='Taylor Swift', figsize=(120, 10), kind ='bar')

# %%
#Plot Interest by Region in Bar Graph
df.reset_index().plot(x='geoName', y='Taylor Swift', figsize=(120, 10), kind ='bar', resolution='ALGERIA')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-3378c2a8dd60> in <module>
#       1 #Plot Interest by Region in Bar Graph
# ----> 2 df.reset_index().plot(x='geoName', y='Taylor Swift', figsize=(120, 10), kind ='bar', resolution='ALGERIA')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     845                     data.columns = label_name
#     846
# --> 847         return plot_backend.plot(data, kind=kind, **kwargs)
#     848
#     849     __call__.__doc__ = __doc__
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
# ...
